# %% [raw]
# ---
# title: "Tidying Our Beatles Metadata"
# author: 'Richard Freedman'
# date: 'September 25, 2024'
#
# format:
#   html:
#     code-fold: false
#     embed-resources: true
# plotly-connected: true
# jupyter: python3
#
# ---

# %% [markdown]
# ## 1. Motivation:  Tidy Up OUR Beatles Metadata
#
# - In this Notebook we will explore various ways to make our data 'Tidy', following Hadley Wickham's principles.
# - We assume that you are already familiar with ways to 'clean' the data.
# - Here we show 'split', 'explode' and 'melt'
#
# #### NOTE:  Freedman already took care of `split()` for the Genre and Context Columns in Our Beatles Metadata.
#
# - After 'exploding' these, you will need to review data to 'clean' it (of white spaces or other inconsistencies you want to correct, just as we did in Clean Data!

# %% [markdown]
# ### 1a.  Load Libraries

# %%
# import libraries

import pandas as pd

# supress warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### 1b. Load CSV Sheets
#
#
# - NOTE THAT THESE LINKS HAVE BEEN CORRECTED AS OF 2/18!
# - In the case of Our Clean Metadata, the file is now a PICKLE, which means it retains the correct datatypes for lists!

# %%
#  Beatles Spotify Data (just clean, not tidy!)
beatles_spotify_csv = 'https://raw.githubusercontent.com/RichardFreedman/Encoding_Music/refs/heads/main/02_Lab_Data/Beatles/Beatles_Spotify_2026.csv'
beatles_spotify = pd.read_csv(beatles_spotify_csv)


# Beatles Billboard Data (clean not tidy!)
beatles_billboard_clean_csv = 'https://docs.google.com/spreadsheets/d/e/2PACX-1vTvOhZSzoa8kwkmYOzwuAGq3Piaujeabu41wVgAhSPfS0IONz2zi_nG5Km_5GO8B8P6tor0r8CacyNF/pub?output=csv'
bb_clean = pd.read_csv(beatles_billboard_clean_csv)


# and perhaps OUR Cleaned Metadata too!  A pickle!
our_cleaned_beatles_metadata_pkl = 'https://github.com/RichardFreedman/Encoding_Music/raw/refs/heads/main/02_Lab_Data/Beatles/our_clean_beatles_data.pkl'
our_clean_beatles = pd.read_pickle(our_cleaned_beatles_metadata_pkl)


# and for final comparison, you can even load a completely pickled exploded and melted version of the billboard and spotify data
beatles_bb_spotify_final = 'https://github.com/RichardFreedman/Encoding_Music/raw/refs/heads/main/02_Lab_Data/Beatles/beatles_data_combined_clean_tidy.pkl'
beatles_bb_spotify_tidy = pd.read_pickle(beatles_bb_spotify_final)

# %% [markdown]
# # 2.  Implementation
#
# ### Here is the plan . . ..
#
# - a) Genre:  explode and clean (again!)
# - c) Combine:  merge the dfs
# - d) Think about OUR data in relation to these

# %%
# a quick view of our df

our_clean_beatles.head()
# Out:
#            Song Title          Your Name  Your Graduating Class  \
# 0   A Day in the Life  Quasebarth, Grace                   2024
# 1   A Day in the Life  Quasebarth, Grace                   2024
# 2         Love You To  Quasebarth, Grace                   2024
# 3            Hey Jude  Quasebarth, Grace                   2024
# 4  Ob-La-Di, Ob-La-Da  Quasebarth, Grace                   2024
#
#   Team/Group Name  Personal Rank Clean  \
# 0     Ohio Exists                    5
# 1     Ohio Exists                    5
# 2     Ohio Exists                    0
# 3     Ohio Exists                    6
# 4     Ohio Exists                    4
#
#                                          Genre Tags  \
# 0                    [soft rock,  alternative rock]
# 1                    [soft rock,  alternative rock]
# 2  [modern bollywood,  exotica,  indian electronic]
# 3                        [slowcore,  piano rock,  ]
# 4       [soft rock,  indie poptimism,  mellow gold]
#
#                               Most Likely Context(s)  \
# 0  [giant on south 23rd street,  cedar point,  ra...
# 1  [giant on south 23rd street,  cedar point,  ra...
# 2      [radio,  most inconvenient moment imaginable]
# 3  [bar in spain,  cvs,  cedar point,  most incon...
# 4  [southwest airlines,  cvs,  giant on south 23r...
#
#                               Least Likely Contexts  \
# 0                              [southwest airlines]
# 1                              [southwest airlines]
# 2  [cvs,  cedar point,  giant on south 23rd street]
# 3                      [southwest airlines,  radio]
# 4              [bar in spain,  radio,  cedar point]
#
#                                          Spotify URL
# 0  https://open.spotify.com/track/0hKRSZhUGEhKU6a...
# 1  https://open.spotify.com/track/0hKRSZhUGEhKU6a...
# 2  https://open.spotify.com/track/69c15XPo8sYUqmn...
# 3  https://open.spotify.com/track/3m7V717IKZqZLW5...
# 4  https://open.spotify.com/track/1gFNm7cXfG1vSMc...

# %%
# single row from our metadata looks like this:
our_clean_beatles.iloc[0]
# Out:
# Song Title                                                A Day in the Life
# Your Name                                                 Quasebarth, Grace
# Your Graduating Class                                                  2024
# Team/Group Name                                                 Ohio Exists
# Personal Rank Clean                                                       5
# Genre Tags                                   [soft rock,  alternative rock]
# Most Likely Context(s)    [giant on south 23rd street,  cedar point,  ra...
# Least Likely Contexts                                  [southwest airlines]
# Spotify URL               https://open.spotify.com/track/0hKRSZhUGEhKU6a...
# Name: 0, dtype: object

# %%
# confirm the data type of Genre Tags
type(our_clean_beatles.iloc[0]['Genre Tags'])
# Out:
# list

# %% [markdown]
# ### 2a. Tidy Genres with Explode

# %% [markdown]
# #### Why No Need to Split?
#
# - As you can see above, our `Genre Tags` column has *already been `split()`*
# - It contains a `list` of `strings`, and not not a single long `list`!
#
# This:
#
# `['rock & roll', 'pop/rock']`
#
# Not (as it was in Our ORIGINAL Messy Metadata):
#
# `'rock & roll pop/rock'`
#
# So we can go directly to `explode()`!

# %% [markdown]
# ### Explode the lists!
#
# - Humans can make sense of those lists.  But for various steps of grouping, filtering and making charts, it will be better to keep **one genre tag per row**.
# - We can easily do this with a Pandas method called `explode().  Here is how:
#
# ```python
# our_clean_beatles_exploded = our_clean_beatles.explode('Genre Tags').reset_index(drop=True)
# ```

# %%
# explode the data on the genre column, and save that as a new df
our_clean_beatles_exploded = our_clean_beatles.explode('Genre Tags').reset_index(drop=True)
our_clean_beatles_exploded.head()
# Out:
#           Song Title          Your Name  Your Graduating Class  \
# 0  A Day in the Life  Quasebarth, Grace                   2024
# 1  A Day in the Life  Quasebarth, Grace                   2024
# 2  A Day in the Life  Quasebarth, Grace                   2024
# 3  A Day in the Life  Quasebarth, Grace                   2024
# 4        Love You To  Quasebarth, Grace                   2024
#
#   Team/Group Name  Personal Rank Clean         Genre Tags  \
# 0     Ohio Exists                    5          soft rock
# 1     Ohio Exists                    5   alternative rock
# 2     Ohio Exists                    5          soft rock
# 3     Ohio Exists                    5   alternative rock
# 4     Ohio Exists                    0   modern bollywood
#
#                               Most Likely Context(s)  \
# 0  [giant on south 23rd street,  cedar point,  ra...
# 1  [giant on south 23rd street,  cedar point,  ra...
# 2  [giant on south 23rd street,  cedar point,  ra...
# 3  [giant on south 23rd street,  cedar point,  ra...
# 4      [radio,  most inconvenient moment imaginable]
#
#                               Least Likely Contexts  \
# 0                              [southwest airlines]
# 1                              [southwest airlines]
# 2                              [southwest airlines]
# 3                              [southwest airlines]
# 4  [cvs,  cedar point,  giant on south 23rd street]
#
#                                          Spotify URL
# 0  https://open.spotify.com/track/0hKRSZhUGEhKU6a...
# 1  https://open.spotify.com/track/0hKRSZhUGEhKU6a...
# 2  https://open.spotify.com/track/0hKRSZhUGEhKU6a...
# 3  https://open.spotify.com/track/0hKRSZhUGEhKU6a...
# 4  https://open.spotify.com/track/69c15XPo8sYUqmn...

# %% [markdown]
# ### 2b. But now we need to Clean Again!
#
# - Now that the genres have been split into separate rows, we need to check for all the usual problems:
# - white space
# - missing values (which might come from oddities in the original long strings)
# - inconsistent values

# %%
# consider values in exploded genres for clean up:
sorted(our_clean_beatles_exploded['Genre Tags'].fillna('unspecified').unique().tolist())
# Out:
# [' ',
#  '  art rock',
#  '  art rock ',
#  '  big trip hype ',
#  '  cold war nostalgia soft rock',
#  '  easy listening',
#  '  folk rock ',
#  '  groove-music',
#  '  indie',
#  '  lonesome rock',
#  '  plagiarism music',
#  '  pop',
#  '  pop rock ',
#  '  rock',
#  '  rock-n-roll',
#  '  rubbish',
#  ' alternative rock',
#  " children's music",
#  ' doo-wop',
#  ' exotica',
#  ' folk',
#  ' high vibe',
#  ' indian electronic',
#  ' indie poptimism',
#  ' melancholia',
#  ' mellow gold',
#  ' piano rock',
#  ' rock',
#  ' soft rock',
#  'comedy rock',
#  'comrade pop',
#  'folk rock',
#  'garbage',
#  'god-tier',
#  'indie',
#  'modern bollywood',
#  'penitential pop',
#  'plaintive pop',
#  'pop',
#  'pop rock',
#  'psychedelic rock',
#  'rock',
#  'sea shanties',
#  'shanty',
#  'slowcore',
#  'soft rock',
#  'world music rock of the past century',
#  'zoomba tunes']

# %% [markdown]
# - Here is a **function** you can adapt for the job of cleaning!
#
# - In this case our function takes in a COMPLETE COLUMN, not individual values in cells
# - Each line applies a different transformation to the data.  You can remove the ones you don't need, or adapt!
# - Don't forget the closing `)` at the end!

# %%
# cleaning function


def clean_genre(genre_series):
    """
    Clean and standardize genre names.
    
    Parameters:
    genre_series: pandas Series containing genre data
    
    Returns:
    pandas Series with cleaned genre data
    """
    return (genre_series
            .str.strip('[')
            .str.strip()
            .str.replace('pop/rock', 'pop rock', regex=False)
            .str.replace('r&b', 'rhythm and blues', regex=False)
            .str.replace('rock and roll', 'rock', regex=False)
            .str.replace('rock & roll', 'rock', regex=False)
            .str.replace('jazz-pop', 'jazz pop', regex=False)
            .str.replace('experimental music', 'experimental', regex=False)
            .str.replace("children's music", "children's", regex=False)
            .str.replace("folkpop/rock", "folk pop rock", regex=False)
            .str.replace("stage&screen", "stage and screen", regex=False)
            .str.replace("electronic pop/rock", "electronic pop rock", regex=False)
            .str.replace("avant-pop", "avant pop", regex=False)
        
    )

# %%
# our column as a series
our_clean_beatles_exploded['Genre Tags']
# Out:
# 0             soft rock
# 1      alternative rock
# 2             soft rock
# 3      alternative rock
# 4      modern bollywood
#             ...
# 84                 rock
# 85              garbage
# 86              rubbish
# 87        plaintive pop
# 88          rock-n-roll
# Name: Genre Tags, Length: 89, dtype: object

# %%
# designate the series (a column)
selected_series = our_clean_beatles_exploded['Genre Tags']

# pass it in to the function
our_clean_beatles_exploded['Genre Tags'] = clean_genre(selected_series)

# check results
our_clean_beatles_exploded.head()
# Out:
#           Song Title          Your Name  Your Graduating Class  \
# 0  A Day in the Life  Quasebarth, Grace                   2024
# 1  A Day in the Life  Quasebarth, Grace                   2024
# 2  A Day in the Life  Quasebarth, Grace                   2024
# 3  A Day in the Life  Quasebarth, Grace                   2024
# 4        Love You To  Quasebarth, Grace                   2024
#
#   Team/Group Name  Personal Rank Clean        Genre Tags  \
# 0     Ohio Exists                    5         soft rock
# 1     Ohio Exists                    5  alternative rock
# 2     Ohio Exists                    5         soft rock
# 3     Ohio Exists                    5  alternative rock
# 4     Ohio Exists                    0  modern bollywood
#
#                               Most Likely Context(s)  \
# 0  [giant on south 23rd street,  cedar point,  ra...
# 1  [giant on south 23rd street,  cedar point,  ra...
# 2  [giant on south 23rd street,  cedar point,  ra...
# 3  [giant on south 23rd street,  cedar point,  ra...
# 4      [radio,  most inconvenient moment imaginable]
#
#                               Least Likely Contexts  \
# 0                              [southwest airlines]
# 1                              [southwest airlines]
# 2                              [southwest airlines]
# 3                              [southwest airlines]
# 4  [cvs,  cedar point,  giant on south 23rd street]
#
#                                          Spotify URL
# 0  https://open.spotify.com/track/0hKRSZhUGEhKU6a...
# 1  https://open.spotify.com/track/0hKRSZhUGEhKU6a...
# 2  https://open.spotify.com/track/0hKRSZhUGEhKU6a...
# 3  https://open.spotify.com/track/0hKRSZhUGEhKU6a...
# 4  https://open.spotify.com/track/69c15XPo8sYUqmn...

# %%
# check distribution of genres
our_clean_beatles_exploded['Genre Tags'].value_counts().tail(20)
# Out:
# Genre Tags
# indie poptimism                         1
# mellow gold                             1
# shanty                                  1
# children's                              1
# comrade pop                             1
# melancholia                             1
# lonesome rock                           1
# penitential pop                         1
# folk                                    1
# comedy rock                             1
# sea shanties                            1
# cold war nostalgia soft rock            1
# zoomba tunes                            1
# easy listening                          1
# big trip hype                           1
# plagiarism music                        1
# world music rock of the past century    1
# garbage                                 1
# rubbish                                 1
# plaintive pop                           1
# Name: count, dtype: int64

# %%
# save our exploded data locally as csv
our_clean_beatles_exploded.to_pickle('beatles_billboard_clean_explode.pkl')

# and here is how to reload it
our_data_exploded_re = pd.read_pickle('beatles_billboard_clean_explode.pkl')

# %%
our_data_exploded_re
# Out:
#            Song Title           Your Name  Your Graduating Class  \
# 0   A Day in the Life   Quasebarth, Grace                   2024
# 1   A Day in the Life   Quasebarth, Grace                   2024
# 2   A Day in the Life   Quasebarth, Grace                   2024
# 3   A Day in the Life   Quasebarth, Grace                   2024
# 4         Love You To   Quasebarth, Grace                   2024
# ..                ...                 ...                    ...
# 84        Love You To  Garozzo, Elizabeth                   2030
# 85  Run for Your Life       Jahiel, Jacob                   2020
# 86  Run for Your Life       Jahiel, Jacob                   2020
# 87              Help!       Jahiel, Jacob                   2020
# 88              Help!       Jahiel, Jacob                   2020
#
#     Team/Group Name  Personal Rank Clean        Genre Tags  \
# 0       Ohio Exists                    5         soft rock
# 1       Ohio Exists                    5  alternative rock
# 2       Ohio Exists                    5         soft rock
# 3       Ohio Exists                    5  alternative rock
# 4       Ohio Exists                    0  modern bollywood
# ..              ...                  ...               ...
# 84  Team/Group Name                    6              rock
# 85     The Skiffles                    6           garbage
# 86     The Skiffles                    6           rubbish
# 87     The Skiffles                    4     plaintive pop
# 88     The Skiffles                    4       rock-n-roll
#
#                                Most Likely Context(s)  \
# 0   [giant on south 23rd street,  cedar point,  ra...
# 1   [giant on south 23rd street,  cedar point,  ra...
# 2   [giant on south 23rd street,  cedar point,  ra...
# 3   [giant on south 23rd street,  cedar point,  ra...
# 4       [radio,  most inconvenient moment imaginable]
# ..                                                ...
# 84                                 [sitar convention]
# 85                       [while dead,   while asleep]
# 86                       [while dead,   while asleep]
# 87                            [in need,   in the car]
# 88                            [in need,   in the car]
#
#                                 Least Likely Contexts  \
# 0                                [southwest airlines]
# 1                                [southwest airlines]
# 2                                [southwest airlines]
# 3                                [southwest airlines]
# 4    [cvs,  cedar point,  giant on south 23rd street]
# ..                                                ...
# 84                   [when i dont want to hear sitar]
# 85                                     [under duress]
# 86                                     [under duress]
# 87  [with a turtle named gerald,   at a silent ret...
# 88  [with a turtle named gerald,   at a silent ret...
#
#                                           Spotify URL
# 0   https://open.spotify.com/track/0hKRSZhUGEhKU6a...
# 1   https://open.spotify.com/track/0hKRSZhUGEhKU6a...
# 2   https://open.spotify.com/track/0hKRSZhUGEhKU6a...
# 3   https://open.spotify.com/track/0hKRSZhUGEhKU6a...
# 4   https://open.spotify.com/track/69c15XPo8sYUqmn...
# ..                                                ...
# 84  https://open.spotify.com/track/69c15XPo8sYUqmn...
# 85  https://open.spotify.com/track/4gUYV3ktbaOeAK5...
# 86  https://open.spotify.com/track/4gUYV3ktbaOeAK5...
# 87  https://open.spotify.com/track/7DD7eSuYSC5xk2A...
# 88  https://open.spotify.com/track/7DD7eSuYSC5xk2A...
#
# [89 rows x 9 columns]

# %% [markdown]
# ## 2c. Merge the our Data
#
# - We've done this before, but note that in this case the song column is called `song` in one df and `Title` in the other.
# - `pd.merge` can handle this!

# %%
combined_beatles_data = pd.merge(beatles_bb_spotify_tidy, 
                                 our_data_exploded_re, 
                                 left_on='song', 
                                 right_on='Song Title', 
                                 how='inner')
combined_beatles_data
# Out:
#                    song  key  mode    tempo  time_signature  duration_ms  \
# 0     A Day in the Life    4     0  163.219               4       337413
# 1     A Day in the Life    4     0  163.219               4       337413
# 2     A Day in the Life    4     0  163.219               4       337413
# 3     A Day in the Life    4     0  163.219               4       337413
# 4     A Day in the Life    4     0  163.219               4       337413
# ...                 ...  ...   ...      ...             ...          ...
# 1267   Yellow Submarine    1     1  111.398               4       158880
# 1268   Yellow Submarine    1     1  111.398               4       158880
# 1269   Yellow Submarine    1     1  111.398               4       158880
# 1270   Yellow Submarine    1     1  111.398               4       158880
# 1271   Yellow Submarine    1     1  111.398               4       158880
#
#      audio_feature  value  year                         album.debut.uk  ...  \
# 0     danceability  0.364  1967  Sgt. Pepper's Lonely Hearts Club Band  ...
# 1     danceability  0.364  1967  Sgt. Pepper's Lonely Hearts Club Band  ...
# 2     danceability  0.364  1967  Sgt. Pepper's Lonely Hearts Club Band  ...
# 3     danceability  0.364  1967  Sgt. Pepper's Lonely Hearts Club Band  ...
# 4     danceability  0.364  1967  Sgt. Pepper's Lonely Hearts Club Band  ...
# ...            ...    ...   ...                                    ...  ...
# 1267       valence  0.696  1966                               Revolver  ...
# 1268       valence  0.696  1966                               Revolver  ...
# 1269       valence  0.696  1966                               Revolver  ...
# 1270       valence  0.696  1966                               Revolver  ...
# 1271       valence  0.696  1966                               Revolver  ...
#
#      top.50.billboard         Song Title          Your Name  \
# 0                   0  A Day in the Life  Quasebarth, Grace
# 1                   0  A Day in the Life  Quasebarth, Grace
# 2                   0  A Day in the Life  Quasebarth, Grace
# 3                   0  A Day in the Life  Quasebarth, Grace
# 4                   0  A Day in the Life     Tang, Patricia
# ...               ...                ...                ...
# 1267               25   Yellow Submarine  Quasebarth, Grace
# 1268               25   Yellow Submarine  Quasebarth, Grace
# 1269               25   Yellow Submarine  Quasebarth, Grace
# 1270               25   Yellow Submarine  Quasebarth, Grace
# 1271               25   Yellow Submarine  Quasebarth, Grace
#
#      Your Graduating Class      Team/Group Name Personal Rank Clean  \
# 0                     2024          Ohio Exists                   5
# 1                     2024          Ohio Exists                   5
# 2                     2024          Ohio Exists                   5
# 3                     2024          Ohio Exists                   5
# 4                     2026      Team/Group Name                   1
# ...                    ...                  ...                 ...
# 1267                  2027  Romantic Travellers                   2
# 1268                  2024          Ohio Exists                   1
# 1269                  2024          Ohio Exists                   1
# 1270                  2024          Ohio Exists                   1
# 1271                  2027  Romantic Travellers                   2
#
#             Genre Tags                             Most Likely Context(s)  \
# 0            soft rock  [giant on south 23rd street,  cedar point,  ra...
# 1     alternative rock  [giant on south 23rd street,  cedar point,  ra...
# 2            soft rock  [giant on south 23rd street,  cedar point,  ra...
# 3     alternative rock  [giant on south 23rd street,  cedar point,  ra...
# 4     psychedelic rock                                              [car]
# ...                ...                                                ...
# 1267      sea shanties                [kids scuba diving class,  karaoke]
# 1268            shanty                 [cedar point,  southwest airlines]
# 1269        children's                 [cedar point,  southwest airlines]
# 1270              folk                 [cedar point,  southwest airlines]
# 1271      sea shanties                [kids scuba diving class,  karaoke]
#
#              Least Likely Contexts  \
# 0             [southwest airlines]
# 1             [southwest airlines]
# 2             [southwest airlines]
# 3             [southwest airlines]
# 4                        [baptism]
# ...                            ...
# 1267   [lifeguard training course]
# 1268  [bar in spain,  radio,  cvs]
# 1269  [bar in spain,  radio,  cvs]
# 1270  [bar in spain,  radio,  cvs]
# 1271   [lifeguard training course]
#
#                                             Spotify URL
# 0     https://open.spotify.com/track/0hKRSZhUGEhKU6a...
# 1     https://open.spotify.com/track/0hKRSZhUGEhKU6a...
# 2     https://open.spotify.com/track/0hKRSZhUGEhKU6a...
# 3     https://open.spotify.com/track/0hKRSZhUGEhKU6a...
# 4     https://open.spotify.com/track/0hKRSZhUGEhKU6a...
# ...                                                 ...
# 1267  https://open.spotify.com/track/50xwQXPtfNZFKFe...
# 1268  https://open.spotify.com/track/50xwQXPtfNZFKFe...
# 1269  https://open.spotify.com/track/50xwQXPtfNZFKFe...
# 1270  https://open.spotify.com/track/50xwQXPtfNZFKFe...
# 1271  https://open.spotify.com/track/50xwQXPtfNZFKFe...
#
# [1272 rows x 24 columns]

# %% [markdown]
# Final Clean Up of Columns

# %%
# force cols to lower case for simplicity
combined_beatles_data.rename(columns=str.lower, inplace=True)
# drop redundant columns
cols_to_drop = ['song']

# this is called 'list comprehension' and will create a list of those NOT in the exclusion list!
cols_to_keep = [col for col in combined_beatles_data.columns if col not in cols_to_drop]

# now a new df with only the colums we want
combined_beatles_data_brief = combined_beatles_data[cols_to_keep]

# %%
combined_beatles_data_brief.head(5)
# Out:
#    key  mode    tempo  time_signature  duration_ms audio_feature  value  year  \
# 0    4     0  163.219               4       337413  danceability  0.364  1967
# 1    4     0  163.219               4       337413  danceability  0.364  1967
# 2    4     0  163.219               4       337413  danceability  0.364  1967
# 3    4     0  163.219               4       337413  danceability  0.364  1967
# 4    4     0  163.219               4       337413  danceability  0.364  1967
#
#                           album.debut.uk album.debut.us  ... top.50.billboard  \
# 0  Sgt. Pepper's Lonely Hearts Club Band           None  ...                0
# 1  Sgt. Pepper's Lonely Hearts Club Band           None  ...                0
# 2  Sgt. Pepper's Lonely Hearts Club Band           None  ...                0
# 3  Sgt. Pepper's Lonely Hearts Club Band           None  ...                0
# 4  Sgt. Pepper's Lonely Hearts Club Band           None  ...                0
#
#           song title          your name  your graduating class  \
# 0  A Day in the Life  Quasebarth, Grace                   2024
# 1  A Day in the Life  Quasebarth, Grace                   2024
# 2  A Day in the Life  Quasebarth, Grace                   2024
# 3  A Day in the Life  Quasebarth, Grace                   2024
# 4  A Day in the Life     Tang, Patricia                   2026
#
#    team/group name personal rank clean        genre tags  \
# 0      Ohio Exists                   5         soft rock
# 1      Ohio Exists                   5  alternative rock
# 2      Ohio Exists                   5         soft rock
# 3      Ohio Exists                   5  alternative rock
# 4  Team/Group Name                   1  psychedelic rock
#
#                               most likely context(s)  least likely contexts  \
# 0  [giant on south 23rd street,  cedar point,  ra...   [southwest airlines]
# 1  [giant on south 23rd street,  cedar point,  ra...   [southwest airlines]
# 2  [giant on south 23rd street,  cedar point,  ra...   [southwest airlines]
# 3  [giant on south 23rd street,  cedar point,  ra...   [southwest airlines]
# 4                                              [car]              [baptism]
#
#                                          spotify url
# 0  https://open.spotify.com/track/0hKRSZhUGEhKU6a...
# 1  https://open.spotify.com/track/0hKRSZhUGEhKU6a...
# 2  https://open.spotify.com/track/0hKRSZhUGEhKU6a...
# 3  https://open.spotify.com/track/0hKRSZhUGEhKU6a...
# 4  https://open.spotify.com/track/0hKRSZhUGEhKU6a...
#
# [5 rows x 23 columns]

# %%
# save the result as 'pickled' file, to preserve all data types!

combined_beatles_data_brief.to_pickle('beatles_combined_clean_exploded_brief.pkl')

# %% [markdown]
# # 3.  Interpretation:
#
# - What did you learn?
